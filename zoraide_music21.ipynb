# %%
from music21 import *
us = environment.UserSettings()
us.create()

# %%
for key in sorted(us.keys()):
    print(key)
# Out:
# autoDownload
# braillePath
# debug
# directoryScratch
# graphicsPath
# ipythonShowFormat
# lilypondBackend
# lilypondFormat
# lilypondPath
# lilypondVersion
# localCorporaSettings
# localCorpusPath
# localCorpusSettings
# manualCoreCorpusPath
# midiPath
# musescoreDirectPNGPath
# musicxmlPath
# pdfPath
# showFormat
# vectorPath
# warnings
# writeFormat

# %%
us['directoryScratch']='./'

# %%
us['lilypondBackend']='/usr/bin/lilypond'

# %%
us['lilypondPath']='/usr/bin/lilypond'

# %%
us['musicxmlPath']='/usr/bin/lilypond'

# %%
b = corpus.parse('bach/bwv66.6')
b.show('lily.png')

# %%
us['graphicsPath']='/usr/bin/lilypond'

# %%
us['pdfPath']='/usr/bin/lilypond'

# %%
us.getSettingsPath()
# Out:
# PosixPath('/home/jovyan/.music21rc')

# %%
us['musescoreDirectPNGPath']='./MuseScore-2.3.2-x86_64.AppImage'

# %%
filename = ! ls *.png -Art | tail -n 1
print(filename[0])
# Out:
# tmpkn2_84ts.ly.png

# %%
from IPython.display import Image
Image(filename=filename[0])
